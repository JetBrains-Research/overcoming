# %%
import numpy as np
import pandas as pd

# %%
user = pd.read_csv("user.csv")
answer = pd.read_csv("answers.csv")

# %%
start_time = answer.start_time
end_time=answer.end_time
answer['start_stamp'] = pd.to_datetime(start_time)
answer['end_stamp'] = pd.to_datetime(end_time)
answer['time'] = answer.end_stamp - answer.start_stamp
answer['time']=answer['time']/np.timedelta64(1,'s')
answer
# Out:
#     id             user_hid  block_num  task_num answer  \
# 0    1 -8920293166519502928          0         0    NaN
# 1    2 -8920293166519502928          0         1    NaN
# 2    3 -8920293166519502928          0         2    NaN
# 3    4 -8920293166519502928          0         3    NaN
# 4    5 -8920293166519502928          1         0    NaN
# ..  ..                  ...        ...       ...    ...
# 76  77   360633697853145618          0         3    NaN
# 77  78   360633697853145618          1         0    NaN
# 78  79   360633697853145618          1         1    NaN
# 79  80   360633697853145618          1         2    NaN
# 80  81   360633697853145618          1         3    NaN
#
#                     start_time                    end_time  \
# 0   2021-08-03 09:19:24.000000  2021-08-03 09:19:50.602239
# 1   2021-08-03 09:19:50.000000  2021-08-03 09:19:54.490507
# 2   2021-08-03 09:19:54.000000  2021-08-03 09:19:59.893330
# ...
